# %% [markdown]
# # Create resaidual norm files for CREDIT

# %%
import os
import yaml
import copy
import numpy as np
import xarray as xr

# %%
from scipy.stats import gmean

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## FE

# %%
# get variable information from data_preprocessing/config
config_name = os.path.realpath('data_config_FE.yml')

with open(config_name, 'r') as stream:
    conf = yaml.safe_load(stream)

# %%
ds_std = xr.open_dataset('/glade/derecho/scratch/ksha/FastEddy/mean_std/FE_std_04lev_new.nc')
ds_residual = xr.open_dataset('/glade/derecho/scratch/ksha/FastEddy/mean_std/FE_residual_04lev_new.nc')

ds_residual_norm = ds_std * ds_residual

# %%
ds_residual_norm.to_netcdf(
    '/glade/derecho/scratch/ksha/FastEddy/mean_std/FE_std_residual_04lev_new.nc'
)

# %%
# ds_new = xr.open_dataset('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/C404_std_residual_1980_2019_12lev.nc')
# ds_W = xr.open_dataset('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/C404_std_residual_1980_2019_12lev_W.nc')
# ds_old = xr.open_dataset('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/C404_std_residual_1980_2019_15lev_20250629.nc')

# for varname in ds_W.keys():
#     print(f'=================== {varname} ===================')
#     try:
#         print(ds_W[varname].values)
#         print(ds_new[varname].values)
#         print(ds_old[varname].values)
#     except:
#         pass

# %%
ds_residual_norm
# Out:
# <xarray.Dataset>
# Dimensions:  (zIndex: 4)
# Coordinates:
#   * zIndex   (zIndex) int32 1 4 20 40
# Data variables:
#     u        (zIndex) float64 2.966 5.875 8.533 7.336
#     v        (zIndex) float64 2.978 5.809 8.414 7.3
#     w        (zIndex) float64 1.388 4.075 7.606 7.417
#     theta    (zIndex) float64 2.616 1.529 1.26 1.662
#     rho      (zIndex) float64 0.01185 0.007185 0.00617 0.00761
#     qv       (zIndex) float64 0.4913 0.2727 0.1998 0.2708
#     TKE_0    (zIndex) float64 0.6056 0.814 0.8861 0.7438
