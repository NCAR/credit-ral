# %% [markdown]
# # Create resaidual norm files for CREDIT

# %%
import os
import yaml
import copy
import numpy as np
import xarray as xr

# %%
from scipy.stats import gmean

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## ERA5

# %%
# get variable information from data_preprocessing/config
config_name = os.path.realpath('data_config_ERA5.yml')

with open(config_name, 'r') as stream:
    conf = yaml.safe_load(stream)

# %%
ds_std = xr.open_dataset('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/ERA5_6h_std_1980_2019.nc')
ds_residual = xr.open_dataset('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/ERA5_6h_residual_1980_2019.nc')

ds_residual_norm = ds_std * ds_residual

# %%
# ds_residual_norm.to_netcdf(
#     '/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/ERA5_6h_std_residual_1980_2019.nc'
# )

# %% [markdown]
# ## WRF

# %%
# get variable information from data_preprocessing/config
config_name = os.path.realpath('data_config_WRF.yml')

with open(config_name, 'r') as stream:
    conf = yaml.safe_load(stream)

# %%
ds_std = xr.open_dataset('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/C404_6h_std_1980_2019_16lev.nc')
ds_residual = xr.open_dataset('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/C404_6h_residual_1980_2019_16lev.nc')

ds_residual_norm = ds_std * ds_residual

# %%
ds_residual_norm.to_netcdf('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/C404_6h_std_residual_1980_2019_16lev.nc')

# %%
ds = xr.open_dataset('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/C404_6h_mean_1980_2019_16lev.nc')

# %%
ds['WRF_precip'].values
# Out:
# array(0.11036608)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                    (bottom_top: 12)
# Coordinates:
#   * bottom_top                 (bottom_top) float32 0.0 1.0 2.0 ... 10.0 11.0
# Data variables: (12/16)
#     WRF_OLR                    float64 ...
#     WRF_radar_composite        float64 ...
#     WRF_TD2                    float64 ...
#     WRF_T2                     float64 ...
#     WRF_precip                 float64 ...
#     WRF_V10                    float64 ...
#     ...                         ...
#     WRF_column_total_moisture  float64 ...
#     WRF_U                      (bottom_top) float64 ...
#     WRF_V                      (bottom_top) float64 ...
#     WRF_T                      (bottom_top) float64 ...
#     WRF_Q                      (bottom_top) float64 ...
#     WRF_P                      (bottom_top) float64 ...
